# %% [markdown]
# # Modélisation avancée
#
# - Choix de modèles pré-entrainés
# - Optimisation : EarlyStopping , Keras Tuner
#
# Classification:
# - Binaire: Sain/Malade
# - Multiclasse : 4 classes : Normal / Viral_Pneumonia / Lung_Opacity / COVID

# %% [markdown]
# # Les modèles sélectionnés
#
# - VGG16
# - VGG19
# - ResNet50
# - EfficientNetB0
#
# Nous avons sélectionnés ces modèles pour les raisons suivantes:
# - Utilisation des mêmes dimensions des images
# - Dimensions nécessaires sont inférieures aux dimensions des images brutes
# Inconvénient:
# - Besoin de conserver les images en RGB, contrairement à notre approche initiale de remise en Niveau de Gris de toutes les images

# %% [markdown]
# # Les modèles sélectionnés par classification:
# - Binaire Sain / Malade: VGG16, VGG19
# - Multiclasse : ResNet50 et EfficientNetB0
#
# ## Les données
# - 600 images par classe sélectionnés aléatoirement
# - Dimensions par défaut des modèles : 224x224x3 (RGB)

# %% [markdown]
# # Les techniques d'optimisation utilisées
# EfficientNetB0:
# - EarlyStopping : EfficientNetB0
# - Keras Tuning RandomSearch : EfficientNetB0 / VGG16 et VGG19
# - Dégel de couches pré-entrainées : EfficientNetB0 / VGG16 et VGG19
#
# ## Les données
# - 600 images par classe sélectionnés aléatoirement
# - Dimensions standards des modèles
#
# ## Métriques
# - F1 Score
# - Recall
# - Restitution: Matrice de confusion et Rapport de classification
#
# ## Interprétabilité:
# GradCAM

# %% [markdown]
# # Cas 1 - Binaire : Sain / Malade
#
# 1. Taille = 28
# 2. Images = 600 images par classe
# *  Sain = Normal
# *  Malade = 1/3 COVID, 1/3 Viral Pneumonia / 1/3 Lung Opacity

# %%
import matplotlib.pyplot as plt
from PIL import Image

def load_and_display_image(image_path):
    img = Image.open(image_path)
    plt.imshow(img)
    plt.axis('off')  # Cela enlève les axes
    plt.show()

# %% [markdown]
# # VGG 16

# %% [markdown]
# ## Courbe d'entrainement

# %% [markdown]
# ### VGG16 Sain/Malade - Précision

# %%
load_and_display_image("./metriques_courbes/vgg16_entrainement_accuracy.png")

# %%
load_and_display_image("./metriques_courbes/vgg16_entrainement_accuracy.png")

# %% [markdown]
# ### VGG16 Sain/Malade - Perte

# %%
load_and_display_image("./metriques_courbes/vgg16_entrainement_loss.png")

# %% [markdown]
# ### VGG16 Sain/Malade - Matrice de confusion

# %%
load_and_display_image("./metriques_courbes/VGG16_confusion_matrix.png")

# %% [markdown]
# ### VGG16 Sain/Malade - Gradcam

# %%
load_and_display_image("./interpretabilite_gradcam/VGG16_GradCam.png")

# %% [markdown]
# ## VGG19

# %% [markdown]
# ### Courbe d'entrainement

# %% [markdown]
# ### VGG19 Sain/Malade - Précision

# %%
# tous les noms de fichiers
# sparse
mc_28_sparse_dense_accuracy=os.path.join(chemin_principal,'MC_28_Sparse_Dense_Accuracy.png')
mc_28_sparse_train_accuracy=os.path.join(chemin_principal,'MC_28_Sparse_Train_Accuracy.png')
mc_28_sparse_dense_loss=os.path.join(chemin_principal,'MC_28_Sparse_Dense_Loss.png')
mc_28_sparse_train_loss=os.path.join(chemin_principal,'MC_28_Sparse_Train_Loss.png')
mc_28_sparse_cnn_accuracy=os.path.join(chemin_principal,'MC_28_Sparse_CNN_Accuracy.png')
mc_28_sparse_lenet_accuracy=os.path.join(chemin_principal,'MC_28_Sparse_LeNet_Accuracy.png')
mc_28_sparse_val_accuracy=os.path.join(chemin_principal,'MC_28_Sparse_Val_Accuracy.png')
mc_28_sparse_cnn_loss=os.path.join(chemin_principal,'MC_28_Sparse_CNN_Loss.png')
mc_28_sparse_lenet_loss=os.path.join(chemin_principal,'MC_28_Sparse_LeNet_Loss.png')
mc_28_sparse_val_loss=os.path.join(chemin_principal,'MC_28_Sparse_Val_Loss.png')

# no sparse

mc_28_no_sparse_cnn_accuracy=os.path.join(chemin_principal,'MC_28_No_Sparse_CNN_Accuracy.png')
mc_28_no_sparse_lenet_accuracy=os.path.join(chemin_principal,'MC_28_No_Sparse_LeNet_Accuracy.png')
mc_28_no_sparse_val_accuracy=os.path.join(chemin_principal,'MC_28_No_Sparse_Val_Accuracy.png')
mc_28_no_sparse_cnn_loss=os.path.join(chemin_principal,'MC_28_No_Sparse_CNN_Loss.png')
mc_28_no_sparse_lenet_loss=os.path.join(chemin_principal,'MC_28_No_Sparse_LeNet_Loss.png')
mc_28_no_sparse_val_loss=os.path.join(chemin_principal,'MC_28_No_Sparse_Val_Loss.png')
mc_28_no_sparse_dense_accuracy=os.path.join(chemin_principal,'MC_28_No_Sparse_Dense_Accuracy.png')
mc_28_no_sparse_train_accuracy=os.path.join(chemin_principal,'MC_28_No_Sparse_Train_Accuracy.png')
mc_28_no_sparse_dense_loss=os.path.join(chemin_principal,'MC_28_No_Sparse_Dense_Loss.png')
mc_28_no_sparse_train_loss=os.path.join(chemin_principal,'MC_28_No_Sparse_Train_Loss.png')

# %% [markdown]
# ## loss='sparse_categorical_crossentropy'

# %% [markdown]
# ### Accuracy 3 modèles
# - Train accuracy
# - Validation accuracy

# %%
# Charger les images
image1 = plt.imread(mc_28_sparse_train_accuracy)
image2 = plt.imread(mc_28_sparse_val_accuracy)

# Créer une figure et un ensemble d'axes
fig, axes = plt.subplots(1, 2, figsize=(16, 8))  # 1 ligne, 2 colonnes

# Afficher la première image
axes[0].imshow(image1)
axes[0].axis('off')  # Masquer les axes pour la première image

# Afficher la seconde image
axes[1].imshow(image2)
axes[1].axis('off')  # Masquer les axes pour la seconde image

plt.show()

# %% [markdown]
# ### Loss 3 modèles
# - Train loss
# - Validation loss

# %%
# Charger les images
image1 = plt.imread(mc_28_sparse_train_loss)
image2 = plt.imread(mc_28_sparse_val_loss)

# Créer une figure et un ensemble d'axes
fig, axes = plt.subplots(1, 2, figsize=(16, 8))  # 1 ligne, 2 colonnes

# Afficher la première image
axes[0].imshow(image1)
axes[0].axis('off')  # Masquer les axes pour la première image

# Afficher la seconde image
axes[1].imshow(image2)
axes[1].axis('off')  # Masquer les axes pour la seconde image

plt.show()

# %% [markdown]
# ### Accuracy LeNet / Loss LeNet

# %%
# Charger les images
image1 = plt.imread(mc_28_sparse_lenet_accuracy)
image2 = plt.imread(mc_28_sparse_lenet_loss)

# Créer une figure et un ensemble d'axes
fig, axes = plt.subplots(1, 2, figsize=(16, 8))  # 1 ligne, 2 colonnes

# Afficher la première image
axes[0].imshow(image1)
axes[0].axis('off')  # Masquer les axes pour la première image

# Afficher la seconde image
axes[1].imshow(image2)
axes[1].axis('off')  # Masquer les axes pour la seconde image

plt.show()

# %% [markdown]
# ### Accuracy CNN / Loss CNN

# %%
# Charger les images
image1 = plt.imread(mc_28_sparse_cnn_accuracy)
image2 = plt.imread(mc_28_sparse_cnn_loss)

# Créer une figure et un ensemble d'axes
fig, axes = plt.subplots(1, 2, figsize=(16, 8))  # 1 ligne, 2 colonnes

# Afficher la première image
axes[0].imshow(image1)
axes[0].axis('off')  # Masquer les axes pour la première image

# Afficher la seconde image
axes[1].imshow(image2)
axes[1].axis('off')  # Masquer les axes pour la seconde image

plt.show()

# %% [markdown]
# ### Accuracy DENSE / Loss DENSE

# %%
# Charger les images
image1 = plt.imread(mc_28_sparse_dense_accuracy)
image2 = plt.imread(mc_28_sparse_dense_loss)

# Créer une figure et un ensemble d'axes
fig, axes = plt.subplots(1, 2, figsize=(16, 8))  # 1 ligne, 2 colonnes

# Afficher la première image
axes[0].imshow(image1)
axes[0].axis('off')  # Masquer les axes pour la première image

# Afficher la seconde image
axes[1].imshow(image2)
axes[1].axis('off')  # Masquer les axes pour la seconde image

plt.show()

# %% [markdown]
# ## loss='categorical_crossentropy'

# %% [markdown]
# ### Accuracy 3 modèles
# - Train accuracy
# - Validation accuracy

# %%
# Charger les images
image1 = plt.imread(mc_28_no_sparse_train_accuracy)
image2 = plt.imread(mc_28_no_sparse_val_accuracy)

# Créer une figure et un ensemble d'axes
fig, axes = plt.subplots(1, 2, figsize=(16, 8))  # 1 ligne, 2 colonnes

# Afficher la première image
axes[0].imshow(image1)
axes[0].axis('off')  # Masquer les axes pour la première image

# Afficher la seconde image
axes[1].imshow(image2)
axes[1].axis('off')  # Masquer les axes pour la seconde image

plt.show()

# %% [markdown]
# ### Loss 3 modèles
# - Train loss
# - Validation loss

# %%
# Charger les images
image1 = plt.imread(mc_28_no_sparse_train_loss)
image2 = plt.imread(mc_28_no_sparse_val_loss)

# Créer une figure et un ensemble d'axes
fig, axes = plt.subplots(1, 2, figsize=(16, 8))  # 1 ligne, 2 colonnes

# Afficher la première image
axes[0].imshow(image1)
axes[0].axis('off')  # Masquer les axes pour la première image

# Afficher la seconde image
axes[1].imshow(image2)
axes[1].axis('off')  # Masquer les axes pour la seconde image

plt.show()

# %% [markdown]
# ### Accuracy LeNet / Loss LeNet

# %%
# Charger les images
image1 = plt.imread(mc_28_no_sparse_lenet_accuracy)
image2 = plt.imread(mc_28_no_sparse_lenet_loss)

# Créer une figure et un ensemble d'axes
fig, axes = plt.subplots(1, 2, figsize=(16, 8))  # 1 ligne, 2 colonnes

# Afficher la première image
axes[0].imshow(image1)
axes[0].axis('off')  # Masquer les axes pour la première image

# Afficher la seconde image
axes[1].imshow(image2)
axes[1].axis('off')  # Masquer les axes pour la seconde image

plt.show()

# %% [markdown]
# ### Accuracy CNN / Loss CNN

# %%
# Charger les images
image1 = plt.imread(mc_28_no_sparse_cnn_accuracy)
image2 = plt.imread(mc_28_no_sparse_cnn_loss)

# Créer une figure et un ensemble d'axes
fig, axes = plt.subplots(1, 2, figsize=(16, 8))  # 1 ligne, 2 colonnes

# Afficher la première image
axes[0].imshow(image1)
axes[0].axis('off')  # Masquer les axes pour la première image

# Afficher la seconde image
axes[1].imshow(image2)
axes[1].axis('off')  # Masquer les axes pour la seconde image

plt.show()

# %% [markdown]
# ### Accuracy DENSE / Loss DENSE

# %%
# Charger les images
image1 = plt.imread(mc_28_no_sparse_dense_accuracy)
image2 = plt.imread(mc_28_no_sparse_dense_loss)

# Créer une figure et un ensemble d'axes
fig, axes = plt.subplots(1, 2, figsize=(16, 8))  # 1 ligne, 2 colonnes

# Afficher la première image
axes[0].imshow(image1)
axes[0].axis('off')  # Masquer les axes pour la première image

# Afficher la seconde image
axes[1].imshow(image2)
axes[1].axis('off')  # Masquer les axes pour la seconde image

plt.show()

# %%
load_and_display_image("./metriques_courbes/vgg19_entrainement_accuracy.png")

# %% [markdown]
# ### VGG19 Sain/Malade - Perte

# %%
load_and_display_image("./metriques_courbes/vgg19_entrainement_loss.png")

# %% [markdown]
# ### VGG19 Sain/Malade - Matrice de confusion

# %%
load_and_display_image("./metriques_courbes/VGG19_confusion_matrix.png")

# %% [markdown]
# ### VGG19 Sain/Malade - Gradcam

# %%
load_and_display_image("./interpretabilite_gradcam/VGG19_GradCam.png")

# %% [markdown]
# # Cas 2 - Multiclasse

# %% [markdown]
# ## EfficientNet B0

# %% [markdown]
# ## Courbe d'entrainement

# %% [markdown]
# ### EfficientNetB0 Multiclasse - Précision

# %%
load_and_display_image("./metriques_courbes/MC_EfficientNetB0_train_validation_accuracy.png")

# %% [markdown]
# ### EfficientNetB0 Multiclasse - Perte

# %%
load_and_display_image("./metriques_courbes/MC_EfficientNetB0_train_validation_loss.png")

# %% [markdown]
# ### EfficientNetB0 Multiclasse - Matrice de confusion

# %%
load_and_display_image("./metriques_courbes/MC_EfficientNetB0_ba242671f16f4e28ba2172cd27b527a8_confusion_matrix.png")

# %% [markdown]
# ### EfficientNetB0 Multiclasse - Gradcam

# %%
### Non implémenté

# %% [markdown]
# # ResNet 50

# %% [markdown]
# ## Courbe d'entrainement

# %% [markdown]
# ### ResNet 50 Multiclasse - Précision

# %%
load_and_display_image("./metriques_courbes/ResNet50_train_validation_accuracy.png")

# %% [markdown]
# ### ResNet 50 Multiclasse - Perte

# %%
load_and_display_image("./metriques_courbes/ResNet50_train_validation_loss.png")
